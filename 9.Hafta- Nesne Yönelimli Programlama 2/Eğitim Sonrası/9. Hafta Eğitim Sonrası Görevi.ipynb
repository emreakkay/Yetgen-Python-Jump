# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
# Kullanıcının seçimine göre işlem yapıyoruz
import random
import time

class Kumanda:
    def __init__(self):
        self.tv_durumu = False
        self.ses = 0
        self.kanal_listesi = ["TRT", "Kanal D", "NTV", "CNN", "BBC"]
        self.kanal = "TRT"

    def tv_ac(self):
        if self.tv_durumu:
            print("Televizyon zaten açık.")
        else:
            print("Televizyon açılıyor...")
            self.tv_durumu = True

    def tv_kapat(self):
        if not self.tv_durumu:
            print("Televizyon zaten kapalı.")
        else:
            print("Televizyon kapanıyor...")
            self.tv_durumu = False

    def ses_ayarları(self):
        while True:
            cevap = input("Sesi açmak için '+', kısmak için '-', çıkmak için 'q' tuşuna basın.")
            if cevap == "+":
                if self.ses != 32:
                    self.ses += 1
                    print("Ses:", self.ses)
            elif cevap == "-":
                if self.ses != 0:
                    self.ses -= 1
                    print("Ses:", self.ses)
            else:
                print("Ses güncellendi:", self.ses)
                break

    def kanal_ekle(self, kanal_adi):
        print("Kanal ekleniyor...")
        time.sleep(1)
        self.kanal_listesi.append(kanal_adi)
        print("Kanal eklendi.")

    def kanal_sayisi(self):
        print("Toplam", len(self.kanal_listesi), "kanal var.")

    def rastgele_kanal(self):
        rastgele = random.randint(0, len(self.kanal_listesi)-1)
        self.kanal = self.kanal_listesi[rastgele]
        print("Şu anki kanal:", self.kanal)

    def tv_bilgileri(self):
        print("Televizyon Durumu:", self.tv_durumu)
        print("Ses:", self.ses)
        print("Şu anki kanal:", self.kanal)

# Kumanda sınıfından bir nesne oluşturuyoruz
kumanda = Kumanda()

# Kumanda işlemlerini gösteren bir menü yazıyoruz
print("""
Televizyon Kumandası

1. Tv Aç
2. Tv Kapat
3. Ses Ayarları
4. Kanal Ekle
5. Kanal Sayısını Öğrenme
6. Rastgele Kanala Geçme
7. Televizyon Bilgileri

Çıkmak için 'q' tuşuna basın.
""")

# Kullanıcının seçimine göre işlem yapıyoruz
while True:
    secim = input("İşlem seçiniz: ")

    if secim == "q":
        print("Kumanda kapatılıyor...")
        break

    elif secim == "1":
        kumanda.tv_ac()

    elif secim == "2":
        kumanda.tv_kapat()

    elif secim == "3":
        kumanda.ses_ayarları()

    elif secim == "4":
        kanal_isimleri = input("Kanal isimlerini ',' ile ayırarak girin: ")
        kanal_listesi = kanal_isimleri.split(",")
        for kanal in kanal_listesi:
            kumanda.kanal_ekle(kanal)

    elif secim == "5":
        kumanda.kanal_sayisi()

    elif secim == "6":
        kumanda.rastgele_kanal()

    elif secim == "7":
        kumanda.tv_bilgileri()

    else:
        print("Geçersiz işlem.")

# %%
import random
import time

class Kumanda():
    def __init__(self):
        self.tv_durum = False
        self.ses = 0
        self.Kanallist =["TRT","BBC","NTV","ATV","TTNT"]
        self.Kanal = "TRT"
    
    def tv_ac(self):
        if self.tv_durum:
         print("Telefizyon açık ")
        else
         print("televizyon aÇılıyor...")
         self.tv_durum = True

    def tv_kapa(self):
        if self.tv_durum: 
         print("Televizyon kapalı")
        else:
         print("Televizyon kapanıyor")
         self.tv_durum = False
    
    def ses_ayarlari(self):
       while True:
            cevap  = int(input("Sesi açmak için '+', kısmak için '-', çıkmak için 'q' tuşuna basın."))
            if  cevap == "+":
                if self.ses !=32:
                 self.ses +=1
                 print(f"Self ses: {self.ses}")
            elif cevap == "-":
                if self.ses !=0:
                 self.ses -= 1
                 print(f"Self ses: {self.ses}")
            else:
                print(f"Ses güncellendi: {self.ses}")
                break
    
    def Kanalekleme(self,kanaladi):
        print("Kanal ekleniyor")
        time.sleep(1)
        kanal_listesi.append(kanaladi)
        print("Kanal eklendi")
