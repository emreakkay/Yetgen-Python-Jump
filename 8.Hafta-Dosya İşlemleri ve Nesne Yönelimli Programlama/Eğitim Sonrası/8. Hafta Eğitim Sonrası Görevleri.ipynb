# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
import time

def vki_hesaplama(kilo,boy):
    vki= kilo/(boy**2)
    return round(vki,1)

def deger_araligi(vki):
    if vki< 18.5:
        return "zayıf"
    elif vki <= 24.9:
        return "normal kilo"
    elif vki <= 29.9:
        return "Fazla kilo"
    elif vki <=39.9:
        return "Obez"
    elif vki <=40:
        return "Ileri obez"
    
def cikti_olustur(isim,yas,kilo,boy,vki,deger):
        kayittarihi =time.ctime(time.time())

        t1= f"Kullanıcı adı {isim}\n"
        t2= f"Kullanıcını yas,kilo,boy bilgisi {yas},{kilo},{boy}\n"
        t2= f".Yas {yas}\n,Kilo {kilo}\n,Boy {boy}\n"
        t3= f"Vucut kitle endeksi{vki}\n"
        t4= f"Değer aralığı {deger}\n"
        t5= f"oluşturma tarihi {kayittarihi}"
        output = t1+t2+t3+t4+t5
        return output

def main():
     girissayisi= int(input("Kaç kişinin verisini gireceksiniz"))
     for i in range (girissayisi):
        print(f"\n{i+1}. kişi için bilgileri giriniz:")
        isim = input("Kullanıcı ismini giriniz:")
        yas = input("Kullanıcı yaşını giriniz:")
        kilo = float(input("Kullanıcı kilosunu giriniz:"))
        boy = float(input("Kullanıcı boyunu giriniz:"))

        vki = vki_hesaplama(kilo,boy)
        deger = deger_araligi(vki)

        with open("kayitlar.txt","a",encoding="utf-8")as dosya:
            dosya.write(cikti_olustur(isim,yas,kilo,boy,vki,deger))
            print(f"\n{i+1}. kişi kaydedildi.\n")
            print('-'*10)
main()


with open("kayitlar.txt","r",encoding="utf-8")as file:
    for i in file:
        print(i)
# Out:
# 1. kişi için bilgileri giriniz:
#
# 1. kişi kaydedildi.
#
# ----------
# Kullanıcı adı Emre
#
# yas 22
#
# ,kilo 70.0
#
# ,boy 1.75
#
# Vucut kitle endeksi22.9
#
# Değer aralığı normal kilo
#
# oluşturma tarihi Fri Apr 14 15:15:16 2023

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
malzemeler = {
    "Muz": 3.0,
    "Çilek": 4.5,
    "Ananas": 2.5,
    "Elma": 5.0,
    "Armut": 6.0,
    "Süt": 2.0,
    "Yoğurt": 1.5,
    "Bal": 1.0,
}
def Smoothie_malzemeleri():
    print("*************** YETBAR SMOOTHIE MALZEMELERI ***************")
    for malzeme in list(menu.keys):
        print(f"{malzeme.upper()} : {menu[item]} TL")

        
      
def smoothie_satin_al():
    while True:
        print()
        Smoothie_malzemeleri()
        print("")




while True:
    print("*************** YETBAR HOŞ GELDİNİZ ***************")
    print("1. Menüyü görüntüle")
    print("2. Satın alma")
    print("3. Çıkış")
    secim = input("Yapmak istediğiniz işlemi seçin (1-3): ")

    if secim == "1":
        menu_goster()
    elif secim == "2":
        smoothie_satin_al()
    elif secim == "3":
        break
    else:
        print("Geçersiz bir seçim yaptınız. Lütfen tekrar deneyin.")

def smoothie_satin_al():
    while True:

Smoothie_malzemeleri()

# %%
malzemeler = {
    "Muz": 3.0,
    "Çilek": 4.5,
    "Ananas": 2.5,
    "Elma": 5.0,
    "Armut": 6.0,
    "Süt": 2.0,
    "Yoğurt": 1.5,
    "Bal": 1.0,
}

def anamenu():
    print("*************** YETBAR MENÜ ***************")
    for esya in list(malzemeler.keys()):
        print(f"{malzemeler.upper():<10} : {malzemeler{esya}} TL")

def Tekurunhesaplama(urun,adet):
    assert adet>= 0
    if urun not in list(malzemeler.keys()):
        return None
    else:
        return malzemeler[urun]*adet

def satin_alma():

    anamenu()
    print("LÜtfen satın almak istediğiniz ürünü giriniz.Çıkış yapmak için'0'tıklayınız")

    satinAlinanUrun= []
    satinAlmaadedi = []

    son_fiyat= 0

    while 1:
        eklenecek_urun= input("Hangi ürün eklemek istersiniz?")

        if eklenecek_urun == "0":
            print("Fiş kaydediliyor.")
            break

        eklememe_adedi = int(input("Kaç adet eklemek istersiniz"))

        fiyat = Tekurunhesaplama(eklenecek_urun,eklememe_adedi)

        if fiyat is None:
            print("Yanlış bir giriş yaptınız, ürün eklenmedi")

        else:
            print(f"Satın alma ücreti: {fiyat}.\n Satın almayı onaylamak için 'y' iptal etmek için 'n' giriniz")

            check = input("Satın almayı onaylamka istiyor musunuz?")
            
            if check =="y":
                print("Satın alma onaylandı.")
                print('-'*40)

                son_fiyat += fiyat
                satinAlinanUrun.append(eklenecek_urun)

                satinAlmaadedi.append(eklememe_adedi)
                print(f"Ara Toplam: {son_fiyat}")
                print("Satın alma iptal edildi")
                print('-'*40)
    return son_fiyat,satinAlinanUrun,satinAlmaadedi


def main():
    print("YetBar'a hoş geldiniz!\n Menüyü görüntülemek için '1' e smooothie yapmak için '2' e tıklayınız\n Çıkmak için '0' a tıklayınız.")

    program = None

    while 1:
        program = int(input("Tercihiniz"))

        if program <0 or program >2 :
            print("Yanlış bir tercih yaptınız. Lütfen tekrar deneyiniz")

        elif program== 0:
            program("Çıkış yapılıyor \n Sağlıklı günler dileriz.")
            break
        
        elif program ==1:
            anamenu()

        elif program== 2:
            satin_alma_ucreti, satinAlinanUrun,satin_alma_adedi= satin_alma()

            with open("kasa.txt","a") as f:
                f.write("\n")
                







def Smoothie_malzemeleri():
    print("*************** YETBAR SMOOTHIE MALZEMELERI ***************")
    for item in list(malzemeler.keys):
        print(f"{item.upper()} : {malzemeler[item]} TL")

Smoothie_malzemeleri()
# Out:
# *************** YETBAR SMOOTHIE MALZEMELERI ***************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 16
#      13     for item in list(malzemeler.keys):
#      14         print(f"{item.upper()} : {malzemeler[item]} TL")
# ---> 16 Smoothie_malzemeleri()
#
# Cell In[18], line 13, in Smoothie_malzemeleri()
#      11 def Smoothie_malzemeleri():
#      12     print("*************** YETBAR SMOOTHIE MALZEMELERI ***************")
# ---> 13     for item in list(malzemeler.keys):
#      14         print(f"{item.upper()} : {malzemeler[item]} TL")
#
# TypeError: 'builtin_function_or_method' object is not iterable
