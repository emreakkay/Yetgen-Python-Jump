# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız

Sayi = int(input("Lütfen bir sayı giriniz:"))
if Sayi > 0:
    print("Sayınız 0'dan büyük ve pozitiftir.")
elif Sayi == 0:
    print("Sayınız 0'eşittir")
elif Sayi < 0:
    print("Sayınız 0 dan küçüktür ve negatiftir.")
# Out:
# Sayınız 0'dan büyük ve pozitiftir.

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
# 2.Problemin Çözümünü Buraya Yazınız

Sayi = int(input("Lütfen bir sayı giriniz:"))

sum = 0

for i in range(1,Sayi):
    if Sayi % i ==0:
     sum+= i
if sum == Sayi:
    print(f"{Sayi} bir mükemmel sayıdır.")
elif sum!= Sayi:
    print(f"{Sayi} bir mükemmel sayı değildir.")
# Out:
# 6 bir mükemmel sayıdır.

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
# 3.Problemin Çözümünü Buraya Yazınız
sayi = input("Bir sayı girin: ")

basamak_sayisi = len(sayi)

toplam = 0

for rakam in sayi:
    toplam += int(rakam) ** basamak_sayisi

if toplam == int(sayi):
    print(sayi, "Armstrong sayısıdır.")
else:
    print(sayi, "Armstrong sayısı değildir.")
# Out:
# 541235 Armstrong sayısı değildir.

# %%
# 1 ile 10000 arasındaki Armstrong sayılarını gir

for sayi in range(1, 10001):
    # Sayının basamak sayısını hesapla
    basamak_sayisi = len(str(sayi))

    # Basamaklardaki rakamları toplamak için bir değişken oluşturun
    toplam = 0

    # Her basamağı ayrı ayrı işle
    for rakam in str(sayi):
        # Rakamın kuvvetini hesapla ve toplama ekle
        toplam += int(rakam) ** basamak_sayisi

    # Sonucu kontrol et
    if toplam == sayi:
        print(sayi, "Armstrong sayısıdır.")
# Out:
# 1 Armstrong sayısıdır.
# 2 Armstrong sayısıdır.
# 3 Armstrong sayısıdır.
# 4 Armstrong sayısıdır.
# 5 Armstrong sayısıdır.
# 6 Armstrong sayısıdır.
# 7 Armstrong sayısıdır.
# 8 Armstrong sayısıdır.
# 9 Armstrong sayısıdır.
# 153 Armstrong sayısıdır.
# 370 Armstrong sayısıdır.
# 371 Armstrong sayısıdır.
# 407 Armstrong sayısıdır.
# 1634 Armstrong sayısıdır.
# 8208 Armstrong sayısıdır.
# 9474 Armstrong sayısıdır.

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
# 4.Problemin Çözümünü Buraya Yazınız
for i in range(1, 11):
    for j in range(1, 5):
        print(f"{i} x {j} = {i*j} ",end='\t')
    print()
# Out:
# 1 x 1 = 1 	1 x 2 = 2 	1 x 3 = 3 	1 x 4 = 4
# 2 x 1 = 2 	2 x 2 = 4 	2 x 3 = 6 	2 x 4 = 8
# 3 x 1 = 3 	3 x 2 = 6 	3 x 3 = 9 	3 x 4 = 12
# 4 x 1 = 4 	4 x 2 = 8 	4 x 3 = 12 	4 x 4 = 16
# 5 x 1 = 5 	5 x 2 = 10 	5 x 3 = 15 	5 x 4 = 20
# 6 x 1 = 6 	6 x 2 = 12 	6 x 3 = 18 	6 x 4 = 24
# 7 x 1 = 7 	7 x 2 = 14 	7 x 3 = 21 	7 x 4 = 28
# 8 x 1 = 8 	8 x 2 = 16 	8 x 3 = 24 	8 x 4 = 32
# 9 x 1 = 9 	9 x 2 = 18 	9 x 3 = 27 	9 x 4 = 36
# 10 x 1 = 10 	10 x 2 = 20 	10 x 3 = 30 	10 x 4 = 40

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
Toplam = 0

while True:
  islem = input("Lütfen ürünün fiyatını giriniz yada q tuşuna basıp çıkınız")
  
  if islem == "q":
    print("İşleminiz btmiştir")
    break
  print("Girdiğiniz fiyat:",islem)
  Toplam +=int(islem)

print("Son fiyat:",Toplam)
# Out:
# Girdiğiniz fiyat: 5412
# Girdiğiniz fiyat: 54215
# Girdiğiniz fiyat: 54125
# Girdiğiniz fiyat: 545
# İşleminiz btmiştir
# Son fiyat: 114297

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
# 6.Problemin Çözümünü Buraya Yazınız
for i in range(1,100):
    if i % 3 !=0:
     continue
    else:
        print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
# 7.Problemin Çözümünü Buraya Yazınız

for i in range(1,100):
    if i % 3 ==0:
        print("Yet")
    elif i % 5 ==0:
        print("Gen")
    elif i % 15 ==0:
        print("YetGen")
    else:
        print(i)
# Out:
# 1
# 2
# Yet
# 4
# Gen
# Yet
# 7
# 8
# Yet
# Gen
# 11
# Yet
# 13
# 14
# Yet
# 16
# 17
# Yet
# 19
# Gen
# Yet
# 22
# 23
# Yet
# Gen
# 26
# Yet
# 28
# 29
# Yet
# 31
# 32
# Yet
# 34
# Gen
# Yet
# 37
# 38
# Yet
# Gen
# 41
# Yet
# 43
# 44
# Yet
# 46
# 47
# Yet
# 49
# Gen
# Yet
# 52
# 53
# Yet
# Gen
# 56
# Yet
# 58
# 59
# Yet
# 61
# 62
# Yet
# 64
# Gen
# Yet
# 67
# 68
# Yet
# Gen
# 71
# Yet
# 73
# 74
# Yet
# 76
# 77
# Yet
# 79
# Gen
# Yet
# 82
# 83
# Yet
# Gen
# 86
# Yet
# 88
# 89
# Yet
# 91
# 92
# Yet
# 94
# Gen
# Yet
# 97
# 98
# Yet
