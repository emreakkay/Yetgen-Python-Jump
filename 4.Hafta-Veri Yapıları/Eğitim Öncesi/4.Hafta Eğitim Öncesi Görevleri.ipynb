# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
# 1.Problemin Çözümünü Buraya Yazınız
Rehber = { "Ahmet" : "05326781319"}
Kisi = input("Lütfen numarasını görmek istediğiniz kişinin adını giriniz")

if Kisi in Rehber:
    print(f"{Kisi} isimli kişinin numarası şu şekildedir {Rehber[Kisi]}")
else:
    print("Malesef girdiğiniz kişiye ait bir numara yok")
# Out:
# Ahmet isimli kişinin numarası şu şekildedir 05326781319

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
# 2.Problemin Çözümünü Buraya Yazınız
Sirket_calisanlar = {
    "Mehmet Yağız":[40, "Adana", "Direktor"],
    "Sibel Aklar":[36, "Ordu", "Asistan"]}

Calisan = input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin:")

if Calisan in Sirket_calisanlar:
    bigiler = Sirket_calisanlar[Calisan]
    print(f"{Calisan} = Memleket:{bigiler[1]} Yaş:{bigiler[0]} Görev:{bigiler[2]} ")
else:
    print("Malesef", Calisan, "isminde bir çalışan bulunamadı")
# Out:
# Malesef EMRE isminde bir çalışan bulunamadı

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
# 3.Problemin Çözümünü Buraya Yazınız
ogrenci_Notlar = {"Mehmet" : [72,66,48],
          "Emre" : [65,45,96],
          "Belkis": [86,78,96]
          }

ogrenci = input("JHangi öğrencinin notlarını görmek istersiniz")

if ogrenci in ogrenci_Notlar:
    notlar = ogrenci_Notlar[ogrenci]
    print(f"{ogrenci} isimli öğrencinin")
    print(f"1.Sınav Notu : {notlar[0]}")
    print(f"2.Sınav Notu : {notlar[1]}")
    print(f"3.Sınav Notu : {notlar[2]}") 
    print(f"Not Ortlaması : {(notlar[0]+notlar[1]+notlar[2])/3}")
else:
    print("Malesef", ogrenci, "isminde bir öğrenci bulunamadı")
# Out:
# Malesef  isminde bir öğrenci bulunamadı

# %%
# 3.Problemin Çözümünü Buraya Yazınız
ogrenci_notlari = {
    "Ahmet": [80, 70, 85],
    "Mehmet": [72, 66, 48],
    "Ayşe": [90, 95, 87]}

ogrenci_adi = input("Lütfen notlarını görmek istediğiniz öğrencinin adını girin: ")

if ogrenci_adi in ogrenci_notlari:
    notlar = ogrenci_notlari[ogrenci_adi]
    print(f"{ogrenci_adi} isimli öğrencinin")
    print(f"1. Sınav Notu: {notlar[0]}")
    print(f"2. Sınav Notu: {notlar[1]}")
    print(f"3. Sınav Notu: {notlar[2]}")
    not_ortalamasi = sum(notlar) / len(notlar)
    print(f"Not Ortalaması: {not_ortalamasi:.1f}")
else:
    print("Girdiğiniz isimde bir öğrenci bulunamadı.")
# Out:
# Ahmet isimli öğrencinin
# 1. Sınav Notu: 80
# 2. Sınav Notu: 70
# 3. Sınav Notu: 85
# Not Ortalaması: 78.3

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.

# 2-  Liste Kaç elemanlıdır ?

# 3-  Listenin ilk ve son elemanı nedir ?

# 4-  Mazda değerini Toyota ile değiştirin.

# 5-  Listenin -2 indeksindeki değer nedir ?

# 6-  Listenin ilk 3 elemanını alın.

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.

# 9- Listenin son elemanını silin.

# 10- Liste elemanlarını tersten yazdırınız.

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 



# 12- Liste elemanlarını ekrana yazdırınız.



  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.


# 14-  "Sena" değerini listenin başına ekleyiniz.


# 15-  "Deniz" ismini listeden siliniz.


# 16-  "Ali" listenin bir elemanı mıdır ?

# 17-  Liste elemanlarını ters çevirin.

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.


# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.


# 21- years dizisinde kaç tane 1998 değeri vardır ?


# 22- years dizisinin tüm elemanlarını siliniz.


# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
# Out:
# 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
Markalar = ["Bmw", "Mercedes", "Opel", "Mazda"]

# %%
# 2-  Liste Kaç elemanlıdır ?
print(len(Markalar))
# Out:
# 4

# %%
# 3-  Listenin ilk ve son elemanı nedir ?
print(Markalar[0])
print(Markalar[-1])
# Out:
# Bmw
# Mazda

# %%
# 4-  Mazda değerini Toyota ile değiştirin.
Markalar[3] = "Toyota"
print(Markalar)
# Out:
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']

# %%
# 5-  Listenin -2 indeksindeki değer nedir ?
print(Markalar[-2])
# Out:
# Opel

# %%
# 6-  Listenin ilk 3 elemanını alın.
print(Markalar[:3])
# Out:
# ['Bmw', 'Mercedes', 'Opel']

# %%
# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
Markalar[-1] = "Toyota"
Markalar[-2] = "Renault"
Markalar
# Out:
# ['Bmw', 'Mercedes', 'Renault', 'Toyota']

# %%
# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
Markalar.append("Audi")
Markalar.append("Nissan")
Markalar
# Out:
# ['Bmw', 'Mercedes', 'Renault', 'Toyota', 'Audi', 'Nissan']

# %%
# 9- Listenin son elemanını silin.
Markalar.pop()
Markalar
# Out:
# ['Bmw', 'Mercedes', 'Renault', 'Toyota', 'Audi']

# %%
# 10- Liste elemanlarını tersten yazdırınız.
Markalar.reverse()
Markalar
# Out:
# ['Audi', 'Toyota', 'Renault', 'Mercedes', 'Bmw']

# %%
# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 

Veriler = ["Yiğit Bilgi:[2010, (70,60,70)","Sena Turan:  1999, (80,80,70)", "Ahmet Turan : 1998, (80,70,90)"]

print(Veriler[1])
# Out:
# Sena Turan:  1999, (80,80,70)

# %%
# 12- Liste elemanlarını ekrana yazdırınız.

names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]
print(names)
print(years)
# Out:
# ['Ali', 'Yağmur', 'Hakan', 'Deniz']
# [1998, 2000, 1998, 1987]

# %%
# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
names
# Out:
# ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']

# %%
# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0,"Sena")
names
# Out:
# ['Sena', 'Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']

# %%
# 15-  "Deniz" ismini listeden siliniz.
names.remove("Deniz")
names
# Out:
# ['Sena', 'Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']

# %%
# 16-  "Ali" listenin bir elemanı mıdır ?
"Ali" in names
# Out:
# True

# %%
# 17-  Liste elemanlarını ters çevirin.
names.reverse()
names
# Out:
# ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena', 'Sena']

# %%
# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
names
# Out:
# ['Ali', 'Cenk', 'Hakan', 'Sena', 'Sena', 'Yağmur']

# %%
# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()
years
# Out:
# [1987, 1998, 1998, 2000]

# %%
# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str = list(("Chevrolet","Dacia"))

# %%
years = [1998, 2000, 1998, 1987]

# %%
# 21- years dizisinde kaç tane 1998 değeri vardır ?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 3
#       1 # 21- years dizisinde kaç tane 1998 değeri vardır ?
#       2 Adet=0
# ----> 3 for i in range(years):
#       4     if i ==1998:
#       5         Adet+=1
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()
years
# Out:
# []

# %%
# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
Markalar = []
i=1
while i<4:
    Marka = input("Lütfen marka bilğisi giriniz")
    Markalar.append(Marka)
    i+=1

print(Markalar)
# Out:
# ['Bugatti', 'Bmw', 'Audi']
